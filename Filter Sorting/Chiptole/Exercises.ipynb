# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas  as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipko = pd.read_csv('file.tsv', delimiter='\t')
chipko
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipko['item_price']=chipko['item_price'].str.replace('$','').astype(float)
chipko
filtered = chipko['item_price']>10
chipko.loc[filtered,['item_name']].count()
# Out:
# /tmp/ipykernel_19916/1186559162.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chipko['item_price']=chipko['item_price'].str.replace('$','').astype(float)
# item_name    1130
# dtype: int64

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
filtered = chipko['quantity'] ==1
filtere1 = chipko.loc[filtered,['item_name','item_price']]
filtered2 = filtere1.drop_duplicates(subset='item_name')
priceofeachitems = filtered2.reset_index().drop('index',axis=1)
priceofeachitems
# Out:
#                                 item_name  item_price
# 0            Chips and Fresh Tomato Salsa        2.39
# 1                                    Izze        3.39
# 2                        Nantucket Nectar        3.39
# 3   Chips and Tomatillo-Green Chili Salsa        2.39
# 4                            Chicken Bowl       10.98
# 5                           Side of Chips        1.69
# 6                           Steak Burrito       11.75
# 7                        Steak Soft Tacos        9.25
# 8                     Chips and Guacamole        4.45
# 9                    Chicken Crispy Tacos        8.75
# 10                     Chicken Soft Tacos        8.75
# 11                        Chicken Burrito        8.49
# 12                       Barbacoa Burrito        8.99
# 13                       Carnitas Burrito        8.99
# 14                            Canned Soda        1.09
# 15                          Carnitas Bowl        8.99
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
sort = chipko

# %%
sort.sort_values(by='item_name',ascending=True)
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
mostexpensive = chipko.sort_values(by='item_price',ascending=False)
mostexpensive.head()
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
#
#                                      choice_description  item_price
# 3598                                                NaN       44.25
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       35.00
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       35.00
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       33.75

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
filteredw = chipko['item_name'] =='Veggie Salad'
orderslist = chipko.loc[filteredw,'order_id'].count()
print("most of ordered veggie salad ", orderslist)
# Out:
# most of ordered veggie salad  6

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
filtercanddeda = (chipko['item_name'] == 'Canned Soda') & (chipko['quantity'] >1)
print(chipko.loc[filtercanddeda,'order_id'].count(), "times did someone order more than one Canned Soda")
# Out:
# 20 times did someone order more than one Canned Soda
